# %%
from own.create_graph import create_source_to_graph

module_name = 'numpy'
module_function_name='save'
# # cg = create_source_to_graph(module_name, module_function_name='save')
# # module_function_name = None
# # cg = create_source_to_graph(module_name, module_function_name=module_function_name)
# module_function_name='load'
# # module_function_name='ndarray'
# # module_function_name='random'
# module_name = 'tensorflow'
# module_function_name = None
# # module_function_name = 'matrix'
# module_function_name = 'simple_nn_layer'
# module_function_name = 'function'
# module_function_name = 'keras'
# module_name = 'tensorflow.keras'
# module_function_name = 'Sequential'
# # module_name = 'tensorflow.keras.Sequential'
# # module_function_name = None
cg = create_source_to_graph(module_name, module_function_name=module_function_name)
cg.graph
# Out:
# 0 g

# %%
print(cg.graph.source)
# Out:
# digraph root {
# 	n00 [label="@array_function_dispatch(_save_dispatcher)"]
# 	n01 [label="def save(file, arr, allow_pickle=True, fix_imports=True):"]
# 	subgraph subgraphn02_1 {
# 		color=blue style=filled
# 		label=subgraphn02_1
# 		n02 [label="own_fid = False"]
# 		n03 [label="if hasattr(file, 'read'):"]
# 		subgraph subgraphn04_2 {
# 			color=blue style=filled
# 			label=subgraphn04_2
# 			n04 [label="fid = file"]
# 			n03 -> n04
# 		}
# 		n05 [label="else:"]
# 		subgraph subgraphn06_2 {
# 			color=blue style=filled
# 			label=subgraphn06_2
# 			n06 [label="file = os_fspath(file)"]
# 			n07 [label="if not file.endswith('.npy'):"]
# 			subgraph subgraphn08_3 {
# 				color=blue style=filled
# 				label=subgraphn08_3
# 				n08 [label="file = file + '.npy'"]
# 				n07 -> n08
# 			}
# 			n09 [label="fid = open(file, 'wb')"]
# 			n10 [label="own_fid = True"]
# 			n05 -> n06
# 			n06 -> n07
# 			n07 -> n08
# 			n08 -> n09
# 			n09 -> n10
# 		}
# 		n12 [label="if sys.version_info[0] >= 3:"]
# 		subgraph subgraphn13_2 {
# 			color=blue style=filled
# 			label=subgraphn13_2
# 			n13 [label="pickle_kwargs = dict(fix_imports=fix_imports)"]
# 			n12 -> n13
# 		}
# 		n14 [label="else:"]
# 		subgraph subgraphn15_2 {
# 			color=blue style=filled
# 			label=subgraphn15_2
# 			n15 [label="# Nothing to do on Python 2"]
# 			n16 [label="pickle_kwargs = None"]
# 			n14 -> n15
# 			n15 -> n16
# 		}
# 		n18 [label="try:"]
# 		subgraph subgraphn19_2 {
# 			color=blue style=filled
# 			label=subgraphn19_2
# 			n19 [label="arr = np.asanyarray(arr)"]
# 			n20 [label="format.write_array(fid, arr, allow_pickle=allow_pickle,   pickle_kwargs=pickle_kwargs)"]
# 			n18 -> n19
# 			n19 -> n20
# 		}
# 		n21 [label="finally:"]
# 		subgraph subgraphn22_2 {
# 			color=blue style=filled
# 			label=subgraphn22_2
# 			n22 [label="if own_fid:"]
# 			subgraph subgraphn23_3 {
# 				color=blue style=filled
# 				label=subgraphn23_3
# 				n23 [label="fid.close()"]
# 				n22 -> n23
# 			}
# 			n21 -> n22
# 			n22 -> n23
# 		}
# 		n01 -> n02
# 		n02 -> n03
# 		n03 -> n04
# 		n04 -> n05
# 		n05 -> n10
# 		n10 -> n12
# 		n12 -> n13
# 		n13 -> n14
# 		n14 -> n16
# 		n16 -> n18
# 		n18 -> n20
# 		n20 -> n21
# 		n21 -> n23
# 	}
# 	n00 -> n01
# 	n01 -> n23
# }

# %%
from own.create_graph import create_source_to_graph

module_name = 'numpy'
module_function_name='save'
# cg = create_source_to_graph(module_name, module_function_name='save')
# module_function_name = None
# cg = create_source_to_graph(module_name, module_function_name=module_function_name)
module_function_name='load'
# module_function_name='ndarray'
# module_function_name='random'
module_name = 'tensorflow'
module_function_name = None
# module_function_name = 'matrix'
module_function_name = 'simple_nn_layer'
module_function_name = 'function'
module_function_name = 'keras'
module_name = 'tensorflow.keras'
module_function_name = 'Sequential'
# module_name = 'tensorflow.keras.Sequential'
# module_function_name = None
cg = create_source_to_graph(module_name, module_function_name=module_function_name)
cg.graph
# Out:
# 0 g

# %%
print(cg.graph.source)
# Out:
# digraph root {
# 	n00 [label="class Sequential(Model):"]
# 	n02 [label="  @checkpointable.no_automatic_dependency_tracking"]
# 	n03 [label="  def __init__(self, layers=None, name=None):"]
# 	subgraph subgraphn04_1 {
# 		color=blue style=filled
# 		label=subgraphn04_1
# 		n04 [label="super(Sequential, self).__init__(name=name)"]
# 		n05 [label="self.supports_masking = True"]
# 		n06 [label="self._build_input_shape = None"]
# 		n07 [label="self._compute_output_and_mask_jointly = True"]
# 		n09 [label="# Add to the model any layers passed to the constructor."]
# 		n10 [label="if layers:"]
# 		n11 [label="  for layer in layers:"]
# 		subgraph subgraphn12_2 {
# 			color=blue style=filled
# 			label=subgraphn12_2
# 			n12 [label="self.add(layer)"]
# 			n11 -> n12
# 		}
# 		n03 -> n04
# 		n04 -> n05
# 		n05 -> n06
# 		n06 -> n07
# 		n07 -> n09
# 		n09 -> n10
# 		n10 -> n11
# 		n11 -> n12
# 	}
# 	n14 [label="  @property"]
# 	n15 [label="  def layers(self):"]
# 	subgraph subgraphn16_1 {
# 		color=blue style=filled
# 		label=subgraphn16_1
# 		n16 [label="# Historically, `sequential.layers` only returns layers that were added"]
# 		n17 [label="# via `add`, and omits the auto-generated `InputLayer` that comes at the"]
# 		n18 [label="# bottom of the stack."]
# 		n19 [label="# `CheckpointableBase` manages the `_layers` attributes and does filtering"]
# 		n20 [label="# over it."]
# 		n21 [label="layers = super(Sequential, self).layers"]
# 		n22 [label="if layers and isinstance(layers[0], InputLayer):"]
# 		n23 [label="  return layers[1:]"]
# 		n24 [label="return layers[:]"]
# 		n15 -> n16
# 		n16 -> n17
# 		n17 -> n18
# 		n18 -> n19
# 		n19 -> n20
# 		n20 -> n21
# 		n21 -> n22
# 		n22 -> n23
# 		n23 -> n24
# 	}
# 	n26 [label="  @checkpointable.no_automatic_dependency_tracking"]
# 	n27 [label="  def add(self, layer):"]
# 	subgraph subgraphn28_1 {
# 		color=blue style=filled
# 		label=subgraphn28_1
# 		n28 [label="if not isinstance(layer, base_layer.Layer):"]
# 		n29 [label="  raise TypeError('The added layer must be '  'an instance of class Layer. '"]
# 		subgraph subgraphn30_2 {
# 			color=blue style=filled
# 			label=subgraphn30_2
# 			subgraph subgraphn30_3 {
# 				color=blue style=filled
# 				label=subgraphn30_3
# 				subgraph subgraphn30_4 {
# 					color=blue style=filled
# 					label=subgraphn30_4
# 					subgraph subgraphn30_5 {
# 						color=blue style=filled
# 						label=subgraphn30_5
# 						n30 [label="  'Found: ' + str(layer))self.built = False"]
# 					}
# 				}
# 			}
# 		}
# 		n31 [label="set_inputs = False"]
# 		n32 [label="if not self._layers:"]
# 		n33 [label="  if isinstance(layer, InputLayer):"]
# 		subgraph subgraphn34_2 {
# 			color=blue style=filled
# 			label=subgraphn34_2
# 			n34 [label="# Corner case where the user passes an InputLayer layer via `add`."]
# 			n35 [label="assert len(layer._inbound_nodes[-1].output_tensors) == 1"]
# 			n36 [label="set_inputs = True"]
# 			n33 -> n34
# 			n34 -> n35
# 			n35 -> n36
# 		}
# 		n37 [label="  else:"]
# 		subgraph subgraphn38_2 {
# 			color=blue style=filled
# 			label=subgraphn38_2
# 			n38 [label="batch_shape, dtype = get_input_shape_and_dtype(layer)"]
# 			n39 [label="if batch_shape:"]
# 			n40 [label="  # Instantiate an input layer."]
# 			n41 [label="  x = Input(  batch_shape=batch_shape,"]
# 			subgraph subgraphn42_3 {
# 				color=blue style=filled
# 				label=subgraphn42_3
# 				n42 [label="  dtype=dtype,"]
# 				n43 [label="  name=layer.name + '_input')  # This will build the current layer"]
# 				n41 -> n42
# 				n42 -> n43
# 			}
# 			n44 [label="  # and create the node connecting the current layer"]
# 			n45 [label="  # to the input layer we just created."]
# 			n46 [label="  layer(x)"]
# 			n47 [label="  set_inputs = True"]
# 			n37 -> n38
# 			n38 -> n39
# 			n39 -> n40
# 			n40 -> n41
# 			n41 -> n43
# 			n43 -> n44
# 			n44 -> n45
# 			n45 -> n46
# 			n46 -> n47
# 		}
# 		n49 [label="  if set_inputs:"]
# 		subgraph subgraphn50_2 {
# 			color=blue style=filled
# 			label=subgraphn50_2
# 			n50 [label="# If an input layer (placeholder) is available."]
# 			n51 [label="if len(layer._inbound_nodes[-1].output_tensors) != 1:"]
# 			n52 [label="  raise ValueError('All layers in a Sequential model '   'should have a single output tensor. '"]
# 			subgraph subgraphn53_3 {
# 				color=blue style=filled
# 				label=subgraphn53_3
# 				subgraph subgraphn53_4 {
# 					color=blue style=filled
# 					label=subgraphn53_4
# 					subgraph subgraphn53_5 {
# 						color=blue style=filled
# 						label=subgraphn53_5
# 						subgraph subgraphn53_6 {
# 							color=blue style=filled
# 							label=subgraphn53_6
# 							n53 [label="   'For multi-output layers, '"]
# 							n54 [label="   'use the functional API.')self.outputs = [layer._inbound_nodes[-1].output_tensors[0]]"]
# 							n53 -> n54
# 						}
# 					}
# 				}
# 			}
# 			n55 [label="self.inputs = layer_utils.get_source_inputs(self.outputs[0])"]
# 			n49 -> n50
# 			n50 -> n51
# 			n51 -> n52
# 			n52 -> n54
# 			n54 -> n55
# 		}
# 		n57 [label="elif self.outputs:"]
# 		n58 [label="  # If the model is being built continuously on top of an input layer:"]
# 		n59 [label="  # refresh its output."]
# 		n60 [label="  output_tensor = layer(self.outputs[0])"]
# 		n61 [label="  if isinstance(output_tensor, list):"]
# 		subgraph subgraphn62_2 {
# 			color=blue style=filled
# 			label=subgraphn62_2
# 			n62 [label="raise TypeError('All layers in a Sequential model ''should have a single output tensor. '"]
# 			subgraph subgraphn63_3 {
# 				color=blue style=filled
# 				label=subgraphn63_3
# 				subgraph subgraphn63_4 {
# 					color=blue style=filled
# 					label=subgraphn63_4
# 					subgraph subgraphn63_5 {
# 						color=blue style=filled
# 						label=subgraphn63_5
# 						subgraph subgraphn63_6 {
# 							color=blue style=filled
# 							label=subgraphn63_6
# 							n63 [label="'For multi-output layers, '"]
# 							n64 [label="'use the functional API.')  self.outputs = [output_tensor]"]
# 							n63 -> n64
# 						}
# 					}
# 				}
# 			}
# 			n61 -> n62
# 			n62 -> n64
# 		}
# 		n65 [label="if set_inputs or self._is_graph_network:"]
# 		n66 [label="  self._init_graph_network(self.inputs, self.outputs, name=self.name)"]
# 		n67 [label="  self.built = True"]
# 		n68 [label="else:"]
# 		n69 [label="  self._layers.append(layer)"]
# 		n70 [label="if self._layers:"]
# 		n71 [label="  self._track_layers(self._layers)"]
# 		n27 -> n28
# 		n28 -> n29
# 		n29 -> n30
# 		n30 -> n31
# 		n31 -> n32
# 		n32 -> n33
# 		n33 -> n36
# 		n36 -> n37
# 		n37 -> n47
# 		n47 -> n49
# 		n49 -> n55
# 		n55 -> n57
# 		n57 -> n58
# 		n58 -> n59
# 		n59 -> n60
# 		n60 -> n61
# 		n61 -> n64
# 		n64 -> n65
# 		n65 -> n66
# 		n66 -> n67
# 		n67 -> n68
# 		n68 -> n69
# 		n69 -> n70
# 		n70 -> n71
# 	}
# 	n73 [label="  @checkpointable.no_automatic_dependency_tracking"]
# 	n74 [label="  def pop(self):"]
# 	subgraph subgraphn75_1 {
# 		color=blue style=filled
# 		label=subgraphn75_1
# 		n75 [label="if not self.layers:"]
# 		n76 [label="  raise TypeError('There are no layers in the model.')"]
# 		n78 [label="self._layers.pop()"]
# 		n79 [label="if not self.layers:"]
# 		n80 [label="  self.outputs = None"]
# 		n81 [label="  self.inputs = None"]
# 		n82 [label="  self.built = False"]
# 		n83 [label="elif self._is_graph_network:"]
# 		n84 [label="  self.layers[-1]._outbound_nodes = []"]
# 		n85 [label="  self.outputs = [self.layers[-1].output]"]
# 		n86 [label="  self._init_graph_network(self.inputs, self.outputs, name=self.name)"]
# 		n87 [label="  self.built = True"]
# 		n74 -> n75
# 		n75 -> n76
# 		n76 -> n78
# 		n78 -> n79
# 		n79 -> n80
# 		n80 -> n81
# 		n81 -> n82
# 		n82 -> n83
# 		n83 -> n84
# 		n84 -> n85
# 		n85 -> n86
# 		n86 -> n87
# 	}
# 	n89 [label="  def build(self, input_shape=None):"]
# 	subgraph subgraphn90_1 {
# 		color=blue style=filled
# 		label=subgraphn90_1
# 		n90 [label="if self._is_graph_network:"]
# 		n91 [label="  self._init_graph_network(self.inputs, self.outputs, name=self.name)"]
# 		n92 [label="else:"]
# 		n93 [label="  if input_shape is None:"]
# 		subgraph subgraphn94_2 {
# 			color=blue style=filled
# 			label=subgraphn94_2
# 			n94 [label="raise ValueError('You must provide an `input_shape` argument.')"]
# 			n93 -> n94
# 		}
# 		n95 [label="  self._build_input_shape = input_shape"]
# 		n96 [label="  shape = input_shape"]
# 		n97 [label="  for layer in self.layers:"]
# 		subgraph subgraphn98_2 {
# 			color=blue style=filled
# 			label=subgraphn98_2
# 			n98 [label="if not layer.built:"]
# 			n99 [label="  with ops.name_scope(layer._name_scope()):"]
# 			subgraph subgraphn100_3 {
# 				color=blue style=filled
# 				label=subgraphn100_3
# 				n100 [label="layer.build(shape)"]
# 				n99 -> n100
# 			}
# 			n101 [label="  layer.built = True"]
# 			n102 [label="shape = layer.compute_output_shape(shape)"]
# 			n97 -> n98
# 			n98 -> n99
# 			n99 -> n100
# 			n100 -> n101
# 			n101 -> n102
# 		}
# 		n103 [label="self.built = True"]
# 		n89 -> n90
# 		n90 -> n91
# 		n91 -> n92
# 		n92 -> n93
# 		n93 -> n94
# 		n94 -> n95
# 		n95 -> n96
# 		n96 -> n97
# 		n97 -> n102
# 		n102 -> n103
# 	}
# 	n105 [label="  def call(self, inputs, training=None, mask=None):"]
# 	subgraph subgraphn106_1 {
# 		color=blue style=filled
# 		label=subgraphn106_1
# 		n106 [label="if self._is_graph_network:"]
# 		n107 [label="  return super(Sequential, self).call(inputs, training=training, mask=mask)"]
# 		n109 [label="outputs, _ = self._call_and_compute_mask(inputs, training=training, mask=mask)"]
# 		n110 [label="return outputs"]
# 		n105 -> n106
# 		n106 -> n107
# 		n107 -> n109
# 		n109 -> n110
# 	}
# 	n112 [label="  def _call_and_compute_mask(self, inputs, training=None, mask=None):"]
# 	subgraph subgraphn113_1 {
# 		color=blue style=filled
# 		label=subgraphn113_1
# 		n113 [label="if not self.built:"]
# 		n114 [label="  self.build(inputs.shape)"]
# 		n116 [label="x = inputs"]
# 		n117 [label="for layer in self.layers:"]
# 		n118 [label="  kwargs = {}"]
# 		n119 [label="  if 'mask' in tf_inspect.getfullargspec(layer.call).args:"]
# 		subgraph subgraphn120_2 {
# 			color=blue style=filled
# 			label=subgraphn120_2
# 			n120 [label="kwargs['mask'] = mask"]
# 			n119 -> n120
# 		}
# 		n121 [label="  if 'training' in tf_inspect.getfullargspec(layer.call).args:"]
# 		subgraph subgraphn122_2 {
# 			color=blue style=filled
# 			label=subgraphn122_2
# 			n122 [label="kwargs['training'] = training"]
# 			n121 -> n122
# 		}
# 		n124 [label="  if isinstance(layer, Network) and layer._compute_output_and_mask_jointly:"]
# 		subgraph subgraphn125_2 {
# 			color=blue style=filled
# 			label=subgraphn125_2
# 			n125 [label="x, mask = layer._call_and_compute_mask(x, **kwargs)"]
# 			n124 -> n125
# 		}
# 		n126 [label="  else:"]
# 		subgraph subgraphn127_2 {
# 			color=blue style=filled
# 			label=subgraphn127_2
# 			n127 [label="x = layer.call(x, **kwargs)"]
# 			n128 [label="if layer.supports_masking:"]
# 			n129 [label="  mask = layer.compute_mask(x, mask)"]
# 			n130 [label="else:"]
# 			n131 [label="  mask = None"]
# 			n126 -> n127
# 			n127 -> n128
# 			n128 -> n129
# 			n129 -> n130
# 			n130 -> n131
# 		}
# 		n132 [label="  if not context.executing_eagerly():"]
# 		subgraph subgraphn133_2 {
# 			color=blue style=filled
# 			label=subgraphn133_2
# 			n133 [label="x._keras_mask = mask"]
# 			n132 -> n133
# 		}
# 		n134 [label="return x, mask"]
# 		n112 -> n113
# 		n113 -> n114
# 		n114 -> n116
# 		n116 -> n117
# 		n117 -> n118
# 		n118 -> n119
# 		n119 -> n120
# 		n120 -> n121
# 		n121 -> n122
# 		n122 -> n124
# 		n124 -> n125
# 		n125 -> n126
# 		n126 -> n131
# 		n131 -> n132
# 		n132 -> n133
# 		n133 -> n134
# 	}
# 	n136 [label="  def compute_output_shape(self, input_shape):"]
# 	subgraph subgraphn137_1 {
# 		color=blue style=filled
# 		label=subgraphn137_1
# 		n137 [label="shape = input_shape"]
# 		n138 [label="for layer in self.layers:"]
# 		n139 [label="  shape = layer.compute_output_shape(shape)"]
# 		n140 [label="return shape"]
# 		n136 -> n137
# 		n137 -> n138
# 		n138 -> n139
# 		n139 -> n140
# 	}
# 	n142 [label="  def compute_mask(self, inputs, mask):"]
# 	subgraph subgraphn143_1 {
# 		color=blue style=filled
# 		label=subgraphn143_1
# 		n143 [label="_, mask = self._call_and_compute_mask(inputs, mask=mask)"]
# 		n144 [label="return mask"]
# 		n142 -> n143
# 		n143 -> n144
# 	}
# 	n146 [label="  def predict_proba(self, x, batch_size=32, verbose=0):"]
# 	subgraph subgraphn147_1 {
# 		color=blue style=filled
# 		label=subgraphn147_1
# 		n147 [label="preds = self.predict(x, batch_size, verbose)"]
# 		n148 [label="if preds.min() < 0. or preds.max() > 1.:"]
# 		n149 [label="  logging.warning('Network returning invalid probability values. '  'The last layer might not normalize predictions '"]
# 		subgraph subgraphn150_2 {
# 			color=blue style=filled
# 			label=subgraphn150_2
# 			subgraph subgraphn150_3 {
# 				color=blue style=filled
# 				label=subgraphn150_3
# 				subgraph subgraphn150_4 {
# 					color=blue style=filled
# 					label=subgraphn150_4
# 					subgraph subgraphn150_5 {
# 						color=blue style=filled
# 						label=subgraphn150_5
# 						n150 [label="  'into probabilities '"]
# 						n151 [label="  '(like softmax or sigmoid would).')return preds"]
# 						n150 -> n151
# 					}
# 				}
# 			}
# 		}
# 		n146 -> n147
# 		n147 -> n148
# 		n148 -> n149
# 		n149 -> n151
# 	}
# 	n153 [label="  def predict_classes(self, x, batch_size=32, verbose=0):"]
# 	subgraph subgraphn154_1 {
# 		color=blue style=filled
# 		label=subgraphn154_1
# 		n154 [label="proba = self.predict(x, batch_size=batch_size, verbose=verbose)"]
# 		n155 [label="if proba.shape[-1] > 1:"]
# 		n156 [label="  return proba.argmax(axis=-1)"]
# 		n157 [label="else:"]
# 		n158 [label="  return (proba > 0.5).astype('int32')"]
# 		n153 -> n154
# 		n154 -> n155
# 		n155 -> n156
# 		n156 -> n157
# 		n157 -> n158
# 	}
# 	n160 [label="  def get_config(self):"]
# 	subgraph subgraphn161_1 {
# 		color=blue style=filled
# 		label=subgraphn161_1
# 		n161 [label="layer_configs = []"]
# 		n162 [label="for layer in self.layers:"]
# 		n163 [label="  layer_configs.append({  'class_name': layer.__class__.__name__,"]
# 		subgraph subgraphn164_2 {
# 			color=blue style=filled
# 			label=subgraphn164_2
# 			n164 [label="  'config': layer.get_config()"]
# 			n163 -> n164
# 		}
# 		n165 [label="  })config = {"]
# 		subgraph subgraphn166_2 {
# 			color=blue style=filled
# 			label=subgraphn166_2
# 			n166 [label="'name': self.name,"]
# 			n167 [label="'layers': copy.deepcopy(layer_configs)"]
# 			n165 -> n166
# 			n166 -> n167
# 		}
# 		n168 [label="}"]
# 		n169 [label="if self._build_input_shape:"]
# 		n170 [label="  config['build_input_shape'] = self._build_input_shape"]
# 		n171 [label="return config"]
# 		n160 -> n161
# 		n161 -> n162
# 		n162 -> n163
# 		n163 -> n164
# 		n164 -> n165
# 		n165 -> n167
# 		n167 -> n168
# 		n168 -> n169
# 		n169 -> n170
# 		n170 -> n171
# 	}
# 	n173 [label="  @classmethod"]
# 	n174 [label="  def from_config(cls, config, custom_objects=None):"]
# 	subgraph subgraphn175_1 {
# 		color=blue style=filled
# 		label=subgraphn175_1
# 		n175 [label="if 'name' in config:"]
# 		n176 [label="  name = config['name']"]
# 		n177 [label="  build_input_shape = config.get('build_input_shape')"]
# 		n178 [label="  layer_configs = config['layers']"]
# 		n179 [label="else:"]
# 		n180 [label="  name = None"]
# 		n181 [label="  build_input_shape = None"]
# 		n182 [label="  layer_configs = config"]
# 		n183 [label="model = cls(name=name)"]
# 		n184 [label="for layer_config in layer_configs:"]
# 		n185 [label="  layer = layer_module.deserialize(layer_config,   custom_objects=custom_objects)"]
# 		n186 [label="  model.add(layer)"]
# 		n187 [label="if not model.inputs and build_input_shape:"]
# 		n188 [label="  model.build(build_input_shape)"]
# 		n189 [label="return model"]
# 		n174 -> n175
# 		n175 -> n176
# 		n176 -> n177
# 		n177 -> n178
# 		n178 -> n179
# 		n179 -> n180
# 		n180 -> n181
# 		n181 -> n182
# 		n182 -> n183
# 		n183 -> n184
# 		n184 -> n185
# 		n185 -> n186
# 		n186 -> n187
# 		n187 -> n188
# 		n188 -> n189
# 	}
# 	n00 -> n02
# 	n02 -> n03
# 	n03 -> n12
# 	n12 -> n14
# 	n14 -> n15
# 	n15 -> n24
# 	n24 -> n26
# 	n26 -> n27
# 	n27 -> n71
# 	n71 -> n73
# 	n73 -> n74
# 	n74 -> n87
# 	n87 -> n89
# 	n89 -> n103
# 	n103 -> n105
# 	n105 -> n110
# 	n110 -> n112
# 	n112 -> n134
# 	n134 -> n136
# 	n136 -> n140
# 	n140 -> n142
# 	n142 -> n144
# 	n144 -> n146
# 	n146 -> n151
# 	n151 -> n153
# 	n153 -> n158
# 	n158 -> n160
# 	n160 -> n171
# 	n171 -> n173
# 	n173 -> n174
# 	n174 -> n189
# }

# %% [markdown]
# ### ソースの変換

# %%
cg.json_data
# Out:
# {'g': {'n00': {'label': 'class Sequential(Model):'},
#   'n02': {'label': '  @checkpointable.no_automatic_dependency_tracking'},
#   'n03': {'label': '  def __init__(self, layers=None, name=None):'},
#   'subgraphn04': {'n04': {'label': 'super(Sequential, self).__init__(name=name)'},
#    'n05': {'label': 'self.supports_masking = True'},
#    'n06': {'label': 'self._build_input_shape = None'},
#    'n07': {'label': 'self._compute_output_and_mask_jointly = True'},
#    'n09': {'label': '# Add to the model any layers passed to the constructor.'},
#    'n10': {'label': 'if layers:'},
#    'n11': {'label': '  for layer in layers:'},
#    'subgraphn12': {'n12': {'label': 'self.add(layer)'}}},
#   'n14': {'label': '  @property'},
#   'n15': {'label': '  def layers(self):'},
#   'subgraphn16': {'n16': {'label': '# Historically, `sequential.layers` only returns layers that were added'},
#    'n17': {'label': '# via `add`, and omits the auto-generated `InputLayer` that comes at the'},
#    'n18': {'label': '# bottom of the stack.'},
#    'n19': {'label': '# `CheckpointableBase` manages the `_layers` attributes and does filtering'},
#    'n20': {'label': '# over it.'},
#    'n21': {'label': 'layers = super(Sequential, self).layers'},
#    'n22': {'label': 'if layers and isinstance(layers[0], InputLayer):'},
#    'n23': {'label': '  return layers[1:]'},
#    'n24': {'label': 'return layers[:]'}},
#   'n26': {'label': '  @checkpointable.no_automatic_dependency_tracking'},
#   'n27': {'label': '  def add(self, layer):'},
#   'subgraphn28': {'n28': {'label': 'if not isinstance(layer, base_layer.Layer):'},
#    'n29': {'label': "  raise TypeError('The added layer must be '  'an instance of class Layer. '"},
#    'subgraphn30': {'subgraphn30': {'subgraphn30': {'subgraphn30': {'n30': {'label': "  'Found: ' + str(layer))self.built = False"}}}}},
#    'n31': {'label': 'set_inputs = False'},
#    'n32': {'label': 'if not self._layers:'},
#    'n33': {'label': '  if isinstance(layer, InputLayer):'},
#    'subgraphn34': {'n34': {'label': '# Corner case where the user passes an InputLayer layer via `add`.'},
#     'n35': {'label': 'assert len(layer._inbound_nodes[-1].output_tensors) == 1'},
#     'n36': {'label': 'set_inputs = True'}},
#    'n37': {'label': '  else:'},
#    'subgraphn38': {'n38': {'label': 'batch_shape, dtype = get_input_shape_and_dtype(layer)'},
#     'n39': {'label': 'if batch_shape:'},
#     'n40': {'label': '  # Instantiate an input layer.'},
#     'n41': {'label': '  x = Input(  batch_shape=batch_shape,'},
#     'subgraphn42': {'n42': {'label': '  dtype=dtype,'},
#      'n43': {'label': "  name=layer.name + '_input')  # This will build the current layer"}},
#     'n44': {'label': '  # and create the node connecting the current layer'},
#     'n45': {'label': '  # to the input layer we just created.'},
#     'n46': {'label': '  layer(x)'},
#     'n47': {'label': '  set_inputs = True'}},
#    'n49': {'label': '  if set_inputs:'},
#    'subgraphn50': {'n50': {'label': '# If an input layer (placeholder) is available.'},
#     'n51': {'label': 'if len(layer._inbound_nodes[-1].output_tensors) != 1:'},
#     'n52': {'label': "  raise ValueError('All layers in a Sequential model '   'should have a single output tensor. '"},
#     'subgraphn53': {'subgraphn53': {'subgraphn53': {'subgraphn53': {'n53': {'label': "   'For multi-output layers, '"},
#         'n54': {'label': "   'use the functional API.')self.outputs = [layer._inbound_nodes[-1].output_tensors[0]]"}}}}},
#     'n55': {'label': 'self.inputs = layer_utils.get_source_inputs(self.outputs[0])'}},
#    'n57': {'label': 'elif self.outputs:'},
#    'n58': {'label': '  # If the model is being built continuously on top of an input layer:'},
#    'n59': {'label': '  # refresh its output.'},
#    'n60': {'label': '  output_tensor = layer(self.outputs[0])'},
#    'n61': {'label': '  if isinstance(output_tensor, list):'},
#    'subgraphn62': {'n62': {'label': "raise TypeError('All layers in a Sequential model ''should have a single output tensor. '"},
#     'subgraphn63': {'subgraphn63': {'subgraphn63': {'subgraphn63': {'n63': {'label': "'For multi-output layers, '"},
#         'n64': {'label': "'use the functional API.')  self.outputs = [output_tensor]"}}}}}},
#    'n65': {'label': 'if set_inputs or self._is_graph_network:'},
#    'n66': {'label': '  self._init_graph_network(self.inputs, self.outputs, name=self.name)'},
#    'n67': {'label': '  self.built = True'},
#    'n68': {'label': 'else:'},
#    'n69': {'label': '  self._layers.append(layer)'},
#    'n70': {'label': 'if self._layers:'},
#    'n71': {'label': '  self._track_layers(self._layers)'}},
#   'n73': {'label': '  @checkpointable.no_automatic_dependency_tracking'},
#   'n74': {'label': '  def pop(self):'},
#   'subgraphn75': {'n75': {'label': 'if not self.layers:'},
#    'n76': {'label': "  raise TypeError('There are no layers in the model.')"},
#    'n78': {'label': 'self._layers.pop()'},
#    'n79': {'label': 'if not self.layers:'},
#    'n80': {'label': '  self.outputs = None'},
#    'n81': {'label': '  self.inputs = None'},
#    'n82': {'label': '  self.built = False'},
#    'n83': {'label': 'elif self._is_graph_network:'},
#    'n84': {'label': '  self.layers[-1]._outbound_nodes = []'},
#    'n85': {'label': '  self.outputs = [self.layers[-1].output]'},
#    'n86': {'label': '  self._init_graph_network(self.inputs, self.outputs, name=self.name)'},
#    'n87': {'label': '  self.built = True'}},
#   'n89': {'label': '  def build(self, input_shape=None):'},
#   'subgraphn90': {'n90': {'label': 'if self._is_graph_network:'},
#    'n91': {'label': '  self._init_graph_network(self.inputs, self.outputs, name=self.name)'},
#    'n92': {'label': 'else:'},
#    'n93': {'label': '  if input_shape is None:'},
#    'subgraphn94': {'n94': {'label': "raise ValueError('You must provide an `input_shape` argument.')"}},
#    'n95': {'label': '  self._build_input_shape = input_shape'},
#    'n96': {'label': '  shape = input_shape'},
#    'n97': {'label': '  for layer in self.layers:'},
#    'subgraphn98': {'n98': {'label': 'if not layer.built:'},
#     'n99': {'label': '  with ops.name_scope(layer._name_scope()):'},
#     'subgraphn100': {'n100': {'label': 'layer.build(shape)'}},
#     'n101': {'label': '  layer.built = True'},
#     'n102': {'label': 'shape = layer.compute_output_shape(shape)'}},
#    'n103': {'label': 'self.built = True'}},
#   'n105': {'label': '  def call(self, inputs, training=None, mask=None):'},
#   'subgraphn106': {'n106': {'label': 'if self._is_graph_network:'},
#    'n107': {'label': '  return super(Sequential, self).call(inputs, training=training, mask=mask)'},
#    'n109': {'label': 'outputs, _ = self._call_and_compute_mask(inputs, training=training, mask=mask)'},
#    'n110': {'label': 'return outputs'}},
#   'n112': {'label': '  def _call_and_compute_mask(self, inputs, training=None, mask=None):'},
#   'subgraphn113': {'n113': {'label': 'if not self.built:'},
#    'n114': {'label': '  self.build(inputs.shape)'},
#    'n116': {'label': 'x = inputs'},
#    'n117': {'label': 'for layer in self.layers:'},
#    'n118': {'label': '  kwargs = {}'},
#    'n119': {'label': "  if 'mask' in tf_inspect.getfullargspec(layer.call).args:"},
#    'subgraphn120': {'n120': {'label': "kwargs['mask'] = mask"}},
#    'n121': {'label': "  if 'training' in tf_inspect.getfullargspec(layer.call).args:"},
#    'subgraphn122': {'n122': {'label': "kwargs['training'] = training"}},
#    'n124': {'label': '  if isinstance(layer, Network) and layer._compute_output_and_mask_jointly:'},
#    'subgraphn125': {'n125': {'label': 'x, mask = layer._call_and_compute_mask(x, **kwargs)'}},
#    'n126': {'label': '  else:'},
#    'subgraphn127': {'n127': {'label': 'x = layer.call(x, **kwargs)'},
#     'n128': {'label': 'if layer.supports_masking:'},
#     'n129': {'label': '  mask = layer.compute_mask(x, mask)'},
#     'n130': {'label': 'else:'},
#     'n131': {'label': '  mask = None'}},
#    'n132': {'label': '  if not context.executing_eagerly():'},
#    'subgraphn133': {'n133': {'label': 'x._keras_mask = mask'}},
#    'n134': {'label': 'return x, mask'}},
#   'n136': {'label': '  def compute_output_shape(self, input_shape):'},
#   'subgraphn137': {'n137': {'label': 'shape = input_shape'},
#    'n138': {'label': 'for layer in self.layers:'},
#    'n139': {'label': '  shape = layer.compute_output_shape(shape)'},
#    'n140': {'label': 'return shape'}},
#   'n142': {'label': '  def compute_mask(self, inputs, mask):'},
#   'subgraphn143': {'n143': {'label': '_, mask = self._call_and_compute_mask(inputs, mask=mask)'},
#    'n144': {'label': 'return mask'}},
#   'n146': {'label': '  def predict_proba(self, x, batch_size=32, verbose=0):'},
#   'subgraphn147': {'n147': {'label': 'preds = self.predict(x, batch_size, verbose)'},
#    'n148': {'label': 'if preds.min() < 0. or preds.max() > 1.:'},
#    'n149': {'label': "  logging.warning('Network returning invalid probability values. '  'The last layer might not normalize predictions '"},
#    'subgraphn150': {'subgraphn150': {'subgraphn150': {'subgraphn150': {'n150': {'label': "  'into probabilities '"},
#        'n151': {'label': "  '(like softmax or sigmoid would).')return preds"}}}}}},
#   'n153': {'label': '  def predict_classes(self, x, batch_size=32, verbose=0):'},
#   'subgraphn154': {'n154': {'label': 'proba = self.predict(x, batch_size=batch_size, verbose=verbose)'},
#    'n155': {'label': 'if proba.shape[-1] > 1:'},
#    'n156': {'label': '  return proba.argmax(axis=-1)'},
#    'n157': {'label': 'else:'},
#    'n158': {'label': "  return (proba > 0.5).astype('int32')"}},
#   'n160': {'label': '  def get_config(self):'},
#   'subgraphn161': {'n161': {'label': 'layer_configs = []'},
#    'n162': {'label': 'for layer in self.layers:'},
#    'n163': {'label': "  layer_configs.append({  'class_name': layer.__class__.__name__,"},
#    'subgraphn164': {'n164': {'label': "  'config': layer.get_config()"}},
#    'n165': {'label': '  })config = {'},
#    'subgraphn166': {'n166': {'label': "'name': self.name,"},
#     'n167': {'label': "'layers': copy.deepcopy(layer_configs)"}},
#    'n168': {'label': '}'},
#    'n169': {'label': 'if self._build_input_shape:'},
#    'n170': {'label': "  config['build_input_shape'] = self._build_input_shape"},
#    'n171': {'label': 'return config'}},
#   'n173': {'label': '  @classmethod'},
#   'n174': {'label': '  def from_config(cls, config, custom_objects=None):'},
#   'subgraphn175': {'n175': {'label': "if 'name' in config:"},
#    'n176': {'label': "  name = config['name']"},
#    'n177': {'label': "  build_input_shape = config.get('build_input_shape')"},
#    'n178': {'label': "  layer_configs = config['layers']"},
#    'n179': {'label': 'else:'},
#    'n180': {'label': '  name = None'},
#    'n181': {'label': '  build_input_shape = None'},
#    'n182': {'label': '  layer_configs = config'},
#    'n183': {'label': 'model = cls(name=name)'},
#    'n184': {'label': 'for layer_config in layer_configs:'},
#    'n185': {'label': '  layer = layer_module.deserialize(layer_config,   custom_objects=custom_objects)'},
#    'n186': {'label': '  model.add(layer)'},
#    'n187': {'label': 'if not model.inputs and build_input_shape:'},
#    'n188': {'label': '  model.build(build_input_shape)'},
#    'n189': {'label': 'return model'}}}}

# %%
# cluster.py - http://www.graphviz.org/content/cluster

from graphviz import Digraph

g = Digraph('G', filename='cluster.gv')

# NOTE: the subgraph name needs to begin with 'cluster' (all lowercase)
#       so that Graphviz recognizes it as a special cluster subgraph

with g.subgraph(name='cluster_0') as c:
    c.attr(style='filled', color='lightgrey')
    c.node_attr.update(style='filled', color='white')
    c.edges([('a0', 'a1'), ('a1', 'a2'), ('a2', 'a3')])
    c.attr(label='process #1')

with g.subgraph(name='cluster_1') as c:
    c.attr(color='blue')
    c.node_attr['style'] = 'filled'
    c.edges([('b0', 'b1'), ('b1', 'b2'), ('b2', 'b3')])
    c.attr(label='process #2')

g.edge('start', 'a0')
g.edge('start', 'b0')
g.edge('a1', 'b3')
g.edge('b2', 'a3')
g.edge('a3', 'a0')
g.edge('a3', 'end')
g.edge('b3', 'end')

g.node('start', shape='Mdiamond')
g.node('end', shape='Msquare')

# g.view()
print(g.source)
# Out:
# digraph G {
# 	subgraph cluster_0 {
# 		node [color=white style=filled]
# 		color=lightgrey style=filled
# 		a0 -> a1
# 		a1 -> a2
# 		a2 -> a3
# 		label="process #1"
# 	}
# 	subgraph cluster_1 {
# 		node [style=filled]
# 		color=blue
# 		b0 -> b1
# 		b1 -> b2
# 		b2 -> b3
# 		label="process #2"
# 	}
# 	start -> a0
# 	start -> b0
# 	a1 -> b3
# 	b2 -> a3
# 	a3 -> a0
# 	a3 -> end
# 	b3 -> end
# 	start [shape=Mdiamond]
# 	end [shape=Msquare]
# }

# %%
import importlib, inspect, graphviz, json
module = importlib.import_module('numpy')

source_lines = inspect.getsourcelines(module)

# %%
source_lines
# Out:
# (['"""\n',
#   'NumPy\n',
#   '=====\n',
#   '\n',
#   'Provides\n',
#   '  1. An array object of arbitrary homogeneous items\n',
#   '  2. Fast mathematical operations over arrays\n',
#   '  3. Linear Algebra, Fourier Transforms, Random Number Generation\n',
#   '\n',
#   'How to use the documentation\n',
#   '----------------------------\n',
#   'Documentation is available in two forms: docstrings provided\n',
#   'with the code, and a loose standing reference guide, available from\n',
#   '`the NumPy homepage <https://www.scipy.org>`_.\n',
#   '\n',
#   'We recommend exploring the docstrings using\n',
#   '`IPython <https://ipython.org>`_, an advanced Python shell with\n',
#   'TAB-completion and introspection capabilities.  See below for further\n',
#   'instructions.\n',
#   '\n',
#   'The docstring examples assume that `numpy` has been imported as `np`::\n',
#   '\n',
#   '  >>> import numpy as np\n',
#   '\n',
#   'Code snippets are indicated by three greater-than signs::\n',
#   '\n',
#   '  >>> x = 42\n',
#   '  >>> x = x + 1\n',
#   '\n',
#   "Use the built-in ``help`` function to view a function's docstring::\n",
#   '\n',
#   '  >>> help(np.sort)\n',
#   '  ... # doctest: +SKIP\n',
#   '\n',
#   'For some objects, ``np.info(obj)`` may provide additional help.  This is\n',
#   'particularly true if you see the line "Help on ufunc object:" at the top\n',
#   'of the help() page.  Ufuncs are implemented in C, not Python, for speed.\n',
#   'The native Python help() does not know how to view their help, but our\n',
#   'np.info() function does.\n',
#   '\n',
#   'To search for documents containing a keyword, do::\n',
#   '\n',
#   "  >>> np.lookfor('keyword')\n",
#   '  ... # doctest: +SKIP\n',
#   '\n',
#   'General-purpose documents like a glossary and help on the basic concepts\n',
#   'of numpy are available under the ``doc`` sub-module::\n',
#   '\n',
#   '  >>> from numpy import doc\n',
#   '  >>> help(doc)\n',
#   '  ... # doctest: +SKIP\n',
#   '\n',
#   'Available subpackages\n',
#   '---------------------\n',
#   'doc\n',
#   '    Topical documentation on broadcasting, indexing, etc.\n',
#   'lib\n',
#   '    Basic functions used by several sub-packages.\n',
#   'random\n',
#   '    Core Random Tools\n',
#   'linalg\n',
#   '    Core Linear Algebra Tools\n',
#   'fft\n',
#   '    Core FFT routines\n',
#   'polynomial\n',
#   '    Polynomial tools\n',
#   'testing\n',
#   '    NumPy testing tools\n',
#   'f2py\n',
#   '    Fortran to Python Interface Generator.\n',
#   'distutils\n',
#   '    Enhancements to distutils with support for\n',
#   '    Fortran compilers support and more.\n',
#   '\n',
#   'Utilities\n',
#   '---------\n',
#   'test\n',
#   '    Run numpy unittests\n',
#   'show_config\n',
#   '    Show numpy build configuration\n',
#   'dual\n',
#   '    Overwrite certain functions with high-performance Scipy tools\n',
#   'matlib\n',
#   '    Make everything matrices.\n',
#   '__version__\n',
#   '    NumPy version string\n',
#   '\n',
#   'Viewing documentation using IPython\n',
#   '-----------------------------------\n',
#   'Start IPython with the NumPy profile (``ipython -p numpy``), which will\n',
#   'import `numpy` under the alias `np`.  Then, use the ``cpaste`` command to\n',
#   'paste examples into the shell.  To see which functions are available in\n',
#   '`numpy`, type ``np.<TAB>`` (where ``<TAB>`` refers to the TAB key), or use\n',
#   '``np.*cos*?<ENTER>`` (where ``<ENTER>`` refers to the ENTER key) to narrow\n',
#   'down the list.  To view the docstring for a function, use\n',
#   '``np.cos?<ENTER>`` (to view the docstring) and ``np.cos??<ENTER>`` (to view\n',
#   'the source code).\n',
#   '\n',
#   'Copies vs. in-place operation\n',
#   '-----------------------------\n',
#   'Most of the functions in `numpy` return a copy of the array argument\n',
#   '(e.g., `np.sort`).  In-place versions of these functions are often\n',
#   'available as array methods, i.e. ``x = np.array([1,2,3]); x.sort()``.\n',
#   'Exceptions to this rule are documented.\n',
#   '\n',
#   '"""\n',
#   'from __future__ import division, absolute_import, print_function\n',
#   '\n',
#   'import sys\n',
#   'import warnings\n',
#   '\n',
#   'from ._globals import ModuleDeprecationWarning, VisibleDeprecationWarning\n',
#   'from ._globals import _NoValue\n',
#   '\n',
#   "# We first need to detect if we're being called as part of the numpy setup\n",
#   '# procedure itself in a reliable manner.\n',
#   'try:\n',
#   '    __NUMPY_SETUP__\n',
#   'except NameError:\n',
#   '    __NUMPY_SETUP__ = False\n',
#   '\n',
#   'if __NUMPY_SETUP__:\n',
#   "    sys.stderr.write('Running from numpy source directory.\\n')\n",
#   'else:\n',
#   '    try:\n',
#   '        from numpy.__config__ import show as show_config\n',
#   '    except ImportError:\n',
#   '        msg = """Error importing numpy: you should not try to import numpy from\n',
#   '        its source directory; please exit the numpy source tree, and relaunch\n',
#   '        your python interpreter from there."""\n',
#   '        raise ImportError(msg)\n',
#   '\n',
#   '    from .version import git_revision as __git_revision__\n',
#   '    from .version import version as __version__\n',
#   '\n',
#   "    __all__ = ['ModuleDeprecationWarning',\n",
#   "               'VisibleDeprecationWarning']\n",
#   '\n',
#   '    # Allow distributors to run custom init code\n',
#   '    from . import _distributor_init\n',
#   '\n',
#   '    from . import core\n',
#   '    from .core import *\n',
#   '    from . import compat\n',
#   '    from . import lib\n',
#   '    from .lib import *\n',
#   '    from . import linalg\n',
#   '    from . import fft\n',
#   '    from . import polynomial\n',
#   '    from . import random\n',
#   '    from . import ctypeslib\n',
#   '    from . import ma\n',
#   '    from . import matrixlib as _mat\n',
#   '    from .matrixlib import *\n',
#   '    from .compat import long\n',
#   '\n',
#   '    # Make these accessible from numpy name-space\n',
#   '    # but not imported in from numpy import *\n',
#   '    if sys.version_info[0] >= 3:\n',
#   '        from builtins import bool, int, float, complex, object, str\n',
#   '        unicode = str\n',
#   '    else:\n',
#   '        from __builtin__ import bool, int, float, complex, object, unicode, str\n',
#   '\n',
#   '    from .core import round, abs, max, min\n',
#   '    # now that numpy modules are imported, can initialize limits\n',
#   '    core.getlimits._register_known_types()\n',
#   '\n',
#   "    __all__.extend(['__version__', 'show_config'])\n",
#   '    __all__.extend(core.__all__)\n',
#   '    __all__.extend(_mat.__all__)\n',
#   '    __all__.extend(lib.__all__)\n',
#   "    __all__.extend(['linalg', 'fft', 'random', 'ctypeslib', 'ma'])\n",
#   '\n',
#   '    # Filter out Cython harmless warnings\n',
#   '    warnings.filterwarnings("ignore", message="numpy.dtype size changed")\n',
#   '    warnings.filterwarnings("ignore", message="numpy.ufunc size changed")\n',
#   '    warnings.filterwarnings("ignore", message="numpy.ndarray size changed")\n',
#   '\n',
#   '    # oldnumeric and numarray were removed in 1.9. In case some packages import\n',
#   '    # but do not use them, we define them here for backward compatibility.\n',
#   "    oldnumeric = 'removed'\n",
#   "    numarray = 'removed'\n",
#   '\n',
#   "    # We don't actually use this ourselves anymore, but I'm not 100% sure that\n",
#   '    # no-one else in the world is using it (though I hope not)\n',
#   '    from .testing import Tester\n',
#   '\n',
#   '    # Pytest testing\n',
#   '    from numpy._pytesttester import PytestTester\n',
#   '    test = PytestTester(__name__)\n',
#   '    del PytestTester\n',
#   '\n',
#   '\n',
#   '    __mkl_version__ = "__MKL_VERSION__"\n',
#   '\n',
#   '    def _sanity_check():\n',
#   '        """\n',
#   '        Quick sanity checks for common bugs caused by environment.\n',
#   '        There are some cases e.g. with wrong BLAS ABI that cause wrong\n',
#   '        results under specific runtime conditions that are not necessarily\n',
#   '        achieved during test suite runs, and it is useful to catch those early.\n',
#   '\n',
#   '        See https://github.com/numpy/numpy/issues/8577 and other\n',
#   '        similar bug reports.\n',
#   '\n',
#   '        """\n',
#   '        try:\n',
#   '            x = ones(2, dtype=float32)\n',
#   '            if not abs(x.dot(x) - 2.0) < 1e-5:\n',
#   '                raise AssertionError()\n',
#   '        except AssertionError:\n',
#   '            msg = ("The current Numpy installation ({!r}) fails to "\n',
#   '                   "pass simple sanity checks. This can be caused for example "\n',
#   '                   "by incorrect BLAS library being linked in, or by mixing "\n',
#   '                   "package managers (pip, conda, apt, ...). Search closed "\n',
#   '                   "numpy issues for similar problems.")\n',
#   '            raise RuntimeError(msg.format(__file__))\n',
#   '\n',
#   '    _sanity_check()\n',
#   '    del _sanity_check\n'],
#  0)
