# %%
import graphviz
from graphviz import Digraph

# %%
graph_source = [
    'digraph untitled {',
    'rankdir=TD',
    'size="4,4"',
    'edge[fontsize="11" arrowhead=open]',
    'start[shape=circle, label="", style=filled]',
    'end[shape=doublecircle, label="", style=filled]',
    'action1[shape=box,style=rounded, label="action"]',
    'action2[shape=box,style=rounded, label="action"]',
    'action3[shape=box,style=rounded, label="action"]',
    'if1[shape=diamond, label="decision"]',
    'if2[shape=diamond, label="decision"]',

    'start -> action1',
    'action1 -> if1[headport=n]',
    'if1 -> action2[label="condition yes" tailport=w]',
    'if1 -> action3[taillabel="condition no" labeldistance=2.5 tailport=e]',
    'action2 -> if2[headport=w]',
    'action3 -> if2[headport=e]',
    'if2 -> end[taillabel="condition"]',
    '}'
]
graph_source = '\n'.join(graph_source)
file_path = 'activate.dot'
with open(file_path, mode='w') as wf:
    wf.write(graph_source)

# %%
print(graph_source)
# Out:
# digraph untitled {
# rankdir=TD
# size="4,4"
# edge[fontsize="11" arrowhead=open]
# start[shape=circle, label="", style=filled]
# end[shape=doublecircle, label="", style=filled]
# action1[shape=box,style=rounded, label="action"]
# action2[shape=box,style=rounded, label="action"]
# action3[shape=box,style=rounded, label="action"]
# if1[shape=diamond, label="decision"]
# if2[shape=diamond, label="decision"]
# start -> action1
# action1 -> if1[headport=n]
# if1 -> action2[label="condition yes" tailport=w]
# if1 -> action3[taillabel="condition no" labeldistance=2.5 tailport=e]
# action2 -> if2[headport=w]
# action3 -> if2[headport=e]
# if2 -> end[taillabel="condition"]
# }

# %%
target_graph = graphviz.Source.from_file(file_path)

# %%
target_graph

# %%
graph_source = [
    'digraph untitled {',
    'rankdir=TD',
    'size="4,4"',
    'edge[fontsize="11" arrowhead=open]',
    'start[label=""]',
    'end[shape=doublecircle, label="", style=filled]',
    'action1[shape=rectangle, label="action"]',
    'action2[shape=rectangle, label="action"]',
    'action3[shape=rectangle, label="action"]',
    'if1[shape=rectangle, label="decision"]',
    'if2[shape=rectangle, label="decision"]',

    'start -> action1',
    'action1 -> if1[headport=n]',
    'if1 -> action2[label="condition yes" tailport=w]',
    'if1 -> action3[taillabel="condition no" labeldistance=2.5 tailport=e]',
    'action2 -> if2[headport=w]',
    'action3 -> if2[headport=e]',
    'if2 -> end[taillabel="condition"]',
    '}'
]
graph_source = '\n'.join(graph_source)
file_path = 'activate.dot'
with open(file_path, mode='w') as wf:
    wf.write(graph_source)
target_graph = graphviz.Source.from_file(file_path)
target_graph

# %%
graph_source = [
    'digraph untitled {',
    'rankdir=TD',
    'size="4,4"',
    'edge[fontsize="11" arrowhead=open]',
    'start[label=""]',
    'end[shape=doublecircle, label="", style=filled]',
    'action1[shape=rectangle, label="action"]',
    'action2[shape=rectangle, label="action"]',
    'action3[shape=rectangle, label="action"]',
    'if1[shape=rectangle, label="decision"]',
    'if2[shape=rectangle, label="decision"]',

    'start -> action1',
    'action1 -> if1',
    'if1 -> action2[label="condition yes" tailport=w]',
    'if1 -> action3[taillabel="condition no" labeldistance=2.5 tailport=e]',
    'action2 -> if2[headport=w]',
    'action3 -> if2[headport=e]',
    'if2 -> end[taillabel="condition"]',
    '}'
]
graph_source = '\n'.join(graph_source)
file_path = 'activate.dot'
with open(file_path, mode='w') as wf:
    wf.write(graph_source)
target_graph = graphviz.Source.from_file(file_path)
target_graph

# %%
graph_source = [
    'digraph untitled {',
    'rankdir=TD',
    'size="4,4"',
    'edge[fontsize="11" arrowhead=open]',
    'start[label=""]',
    'end[shape=doublecircle, label="", style=filled]',
    'action1[shape=rectangle, label="action"]',
    'action2[shape=rectangle, label="action"]',
    'action3[shape=rectangle, label="action"]',
    'if1[shape=rectangle, label="decision"]',
    'if2[shape=rectangle, label="decision"]',

    'start -> action1',
    'action1 -> if1',
    'if1 -> action2[label="condition\nyes" tailport=w]',
    'if1 -> action3[taillabel="condition\nno" labeldistance=2.5 tailport=e]',
    'action2 -> if2[headport=w]',
    'action3 -> if2[headport=e]',
    'if2 -> end[taillabel="condition"]',
    '}'
]
graph_source = '\n'.join(graph_source)
file_path = 'activate.dot'
with open(file_path, mode='w') as wf:
    wf.write(graph_source)
target_graph = graphviz.Source.from_file(file_path)
target_graph

# %%
svg_extension = 'svg'
dot = '.'
file_path = './'
file_name = 'activate-source-1'
g = Digraph(
    format=svg_extension,
    engine='dot'
)

# %%
dir(g)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_a_list',
#  '_attr',
#  '_attr_list',
#  '_attr_plain',
#  '_comment',
#  '_default_extension',
#  '_edge',
#  '_edge_plain',
#  '_encoding',
#  '_engine',
#  '_format',
#  '_head',
#  '_head_strict',
#  '_kwargs',
#  '_node',
#  '_quote',
#  '_quote_edge',
#  '_repr_svg_',
#  '_subgraph',
#  '_subgraph_plain',
#  '_tail',
#  '_view',
#  '_view_darwin',
#  '_view_freebsd',
#  '_view_linux',
#  '_view_windows',
#  'attr',
#  'body',
#  'clear',
#  'comment',
#  'copy',
#  'directed',
#  'directory',
#  'edge',
#  'edge_attr',
#  'edges',
#  'encoding',
# ...

# %%
dir(graphviz)
# Out:
# ['Digraph',
#  'ENGINES',
#  'ExecutableNotFound',
#  'FORMATS',
#  'FORMATTERS',
#  'Graph',
#  'RENDERERS',
#  'RequiredArgumentError',
#  'Source',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__copyright__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__version__',
#  '_compat',
#  'backend',
#  'dot',
#  'escape',
#  'files',
#  'lang',
#  'nohtml',
#  'pipe',
#  'render',
#  'tools',
#  'version',
#  'view']

# %%
from graphviz import Graph

svg_extension = 'svg'
dot = '.'
file_path = './'
file_name = 'activate-graph-1'
p = Graph(
    name='cluster_0',
    format=svg_extension,
    engine='dot'
)
p.edge('a0', 'eggs')

c = Graph(
    name='child',
    node_attr={'shape': 'box'}
)
c.edge('foo', 'bar')

d = Graph(
    name='cluster_1'
)
d.edge('test1', 'test2')
d.node('a3')
d.edge('a3', 'test1')
c.subgraph(d)

p.subgraph(c)
# subgraph_1 = g.subgraph('cluster_0', 'cluster_00', 'cluster_00', 'cluster_00', 'cluster_00')
# subgraph_1.node('a0')
# subgraph_1

p.node('a1')
p.node('a2')

output_file_path = file_path + file_name
p.render(output_file_path, view=False)

p
